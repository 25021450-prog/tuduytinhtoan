# %%
# n=int(input())
# s=0
# for i in range(1,n+1):
#     s+=i
# print(s)

n=int(input())
s=0
i=0
while True:
    i+=1
    s+=i
    if i>=n:
        break
print(s)
# Out:
# 10

# %%
while True:
    n=int(input())
    if n>0:
        break
s=0
for i in range(1,n+1):
    if n%i==0:
        s+=1
if s==2:
    print('la so nguyen to')
else:print('khong phai so nguyen to')
# Out:
# khong phai so nguyen to

# %%
n=int(input())
s=1
for i in range (1,n+1):
    s*=i
print(s)
# Out:
# 6

# %%
n=int(input())
s=0
a=0
while True:
    s+=1
    n//=10
    if n==0:
        break
print(s)
# Out:
# 2

# %%
n=int(input())
day_so=list(map(int,input().split()))
s=False
if len(day_so)==n:
    for i in day_so:
        if i==42:
            s=True
            break
    if s:
        print("I've found the meaning of life!")
    else:
        print("It's a joke!")
else:
    print('vui long nhap day so co n phan tu')
# Out:
# vui long nhap day so co n phan tu

# %%
a,b=map(int,input().split())
s=0
if a>b:
    a,b=b,a
for i in range(a,b+1):
    c=0
    for k in range(1,i+1):
        if i%k==0:
            c+=1
    if c==2:
        s+=i
print(s)
# Out:
# 17

# %%
while True:
    n=int(input())
    if n>=2:
        break
    lon=None

for i in range(1,n+1):
    c=0
    if n%i==0:
        for k in range(1,i+1):
            if i%k==0:
                c+=1
        if c==2:
            lon=i
print(lon)
# Out:
# 7

# %%
n=int(input())
reverse=0
so_buoc=0
while reverse!=n:
    so_buoc+=1
    n+=reverse
    a=n
    reverse=0
    while a!=0:
        b=a%10
        reverse=reverse*10+b
        a//=10
print(reverse,so_buoc)
# Out:
# 33 2

# %%
n=int(input())
n=abs(n)
if n==0:
    print('no number')
else:
    for i in range(1,n+1):
        if i*i<=n:
            a=i*i
            reverse=0
            c=a
            if len(str(c))==1:
                print(c,end=' ')
                continue
            else:
                so_dem=0
                while a!=0:
                    b=a%10
                    a//=10
                    if b in list(map(int,str(a))):
                        break
                    else:
                        so_dem+=1
                if so_dem==len(str(c)):
                    print(c,end=' ')
# Out:
# 1 4 9 16 25 36 49 64 81 169 196 256 289 324 361

# %%
#khi xét đến 1 vẫn tính thêm la 1 bước và mới dừng
n=int(input())
a=0
b=1
count=0
c=1
for i in range(1,n+2):
    count+=1
    if count>a:
        a=count#số lần thức hiện dãy của số b
        b=c
    c=i
    count=0
    while i!=1:
        if i%2==0:
            i/=2
            count+=1
        else:
            i=3*i+1
            count+=1
print(b,a)
# Out:
# 18 21

# %%
n=int(input())
count=0
for i in range(1,n+1):
    if n%i==0 and i%2==0:
        count+=1
print(count)
# Out:
# 6

# %%
n=int(input())
X=int(input('nhap so tien gui vao'))
for i in range(1,n+1):
    X*=(1+0.007)
print(int(X))
# Out:
# 1285467023

# %%
# Out:
# 2
