# %%
n=int(input())
print(n*2)
# Out:
# 4

# %%
a=float(input())
b=float(input())
s=(a*b)-(a*a*3.14)
print(s)

# %%
c = input()
if len(c) != 1:
    print("chi nhap 1 ky tu")
else:
    if c.isupper():
        print("Kết quả:", c.lower())
    elif c.islower():
        print("Kết quả:", c.upper())
    else:
        print("Đây không phải là chữ cái!")
# Out:
# Kết quả: h

# %%
a=input()
if len(a)==1:
    if a.isalpha():
        print(f'{a} la ky tu alphabet')
    elif a.isdigit():
        print(f'{a} la chu so')
    else:
        print('no khong phai ky tu so hay alphabet')
else:
    print('vui long nhap 1 ky tu')
# Out:
# 5 la chu so

# %%
c=input()
if len(c)!=1 or not c.isalpha():
    print('no khong phai ky tu')
else:
    print(chr(ord(c.lower())-1)+' ' +c.lower())
# Out:
# b c

# %%
a,b,c=map(float,input().split())
if a+b<=c:
    print(f'day khong phai canh cua tam giac')
else:
    p=(a+b+c)/2
    s = round(((p*(p-a)*(p-b)*(p-c))**(1/2)),1)
    print(s)
    if a==b==c:
        print(f'tam giac deu') 
    elif a==b or a==c or b==c:
        print(f'tam giac can')   
    elif a**2+b**2==c**2 or a**2+c**2==b**2 or c**2+b**2==a**2:
        print(f'tam giac vuong')
    else:
        print(f'tam giac thuong')
# Out:
# 14.7
# tam giac thuong

# %%
a = input()
if len(a) < 20:
    print(f'vui long nhap du 20 ky tu')
else:
    print(a[4]+a[8])
# Out:
#  t

# %%
ten_chu_ho=input()
Chi_so_thang_truoc=int(input())
Chi_so_thang_nay=int(input())
so_dien=Chi_so_thang_nay-Chi_so_thang_truoc
if 0<so_dien<=50:
    print(f'ho va ten:{ten_chu_ho}')
    print(f'tien phai tra la: {so_dien*1984*1.08}')
elif 50<so_dien<=100:
    print(f'ho va ten:{ten_chu_ho}')
    print(f'tien phai tra la: {so_dien*2050*1.08}')
elif 100<so_dien<=200:
    print(f'ho va ten:{ten_chu_ho}')
    print(f'tien phai tra la: {so_dien*2380*1.08}')
elif 200<so_dien<=300:
    print(f'ho va ten:{ten_chu_ho}')
    print(f'tien phai tra la: {so_dien*2998*1.08}')
elif 300<so_dien<=400:
    print(f'ho va ten:{ten_chu_ho}')
    print(f'tien phai tra la: {so_dien*3350*1.08}')
elif so_dien<0:
    print(f"thang l nay hack")    
else:    
     print(f'ho va ten:{ten_chu_ho}')
     print(f'tien phai tra la: {so_dien*(3460)}')
# Out:
# thang l nay hack
